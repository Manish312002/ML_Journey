# %%
# Importing Pandas
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing

# %%
california_dataset = fetch_california_housing()

print(type(california_dataset))
print(california_dataset)
# Out:
# <class 'sklearn.utils._bunch.Bunch'>
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
california_df = pd.DataFrame(california_dataset.data, columns = california_dataset.feature_names)
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
california_df.shape
# Out:
# (20640, 8)

# %%
# Exporting dataset to csv file or any other format
# california_df.to_csv('California_Dataset.csv', index=False)

# %%
random_df = pd.DataFrame(np.random.rand(30,10))
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.453168  0.866740  0.623778  0.573867  0.632855  0.914658  0.031226
# 1  0.917856  0.043474  0.349887  0.169927  0.803764  0.818355  0.971478
# 2  0.082027  0.598676  0.450301  0.100329  0.501140  0.614382  0.666408
# 3  0.842535  0.473716  0.145909  0.166727  0.859720  0.569341  0.811482
# 4  0.280900  0.401704  0.170969  0.051126  0.459280  0.487317  0.115532
#
#           7         8         9
# 0  0.235333  0.751043  0.842608
# 1  0.444713  0.808882  0.256969
# 2  0.870156  0.843359  0.971960
# 3  0.173089  0.094361  0.039528
# 4  0.866372  0.535184  0.625603

# %%
# california housing dataset shape (rows, columns)
california_df.shape
# Out:
# (20640, 8)

# %%
# california housing dataset First five data points
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# california housing dataset last five data points
california_df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24

# %%
# california housing dataset information
california_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
# Finding no of missing values
california_df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
# Counting values in a column based on labels
california_df.value_counts('HouseAge')
# Out:
# HouseAge
# 52.0    1273
# 36.0     862
# 35.0     824
# 16.0     771
# 17.0     698
# 34.0     689
# 26.0     619
# 33.0     615
# 18.0     570
# 25.0     566
# 32.0     565
# 37.0     537
# 15.0     512
# 19.0     502
# 27.0     488
# 24.0     478
# 30.0     476
# 28.0     471
# 20.0     465
# 29.0     461
# 31.0     458
# 23.0     448
# 21.0     446
# 14.0     412
# 22.0     399
# 38.0     394
# 39.0     369
# 42.0     368
# 44.0     356
# 43.0     353
# 40.0     304
# 13.0     302
# 41.0     296
# 45.0     294
# 10.0     264
# 11.0     254
# 46.0     245
# 5.0      244
# 12.0     238
# 8.0      206
# 9.0      205
# 47.0     198
# 4.0      191
# 48.0     177
# 7.0      175
# 6.0      160
# 50.0     136
# 49.0     134
# 3.0       62
# 2.0       58
# 51.0      48
# 1.0        4
# Name: count, dtype: int64

# %%
# Group the values based on mean
california_df.groupby('HouseAge').mean()
# Out:
#             MedInc  AveRooms  AveBedrms   Population  AveOccup   Latitude  \
# HouseAge
# 1.0       4.003400  9.088091   1.552106   328.500000  3.244088  36.205000
# 2.0       5.167766  7.649087   1.273514  2083.051724  2.747802  35.494483
# 3.0       5.460258  6.851805   1.192486  3001.774194  2.734708  35.284516
# 4.0       5.180673  6.112610   1.116190  2813.162304  2.786138  34.966963
# 5.0       4.697636  5.963211   1.128014  2471.381148  3.279108  35.234262
# 6.0       4.383393  5.832246   1.105839  2165.637500  2.886158  35.233125
# 7.0       4.464457  6.236576   1.145118  2613.080000  2.936948  35.544286
# 8.0       4.459338  6.280481   1.175100  2018.354369  3.360742  35.743835
# 9.0       4.316425  6.014117   1.144547  1886.975610  2.899606  35.683366
# 10.0      4.050508  6.047608   1.195510  1712.924242  2.852738  35.914621
# 11.0      3.932593  6.288396   1.245155  1989.905512  2.932461  35.896063
# ...

# %%
# Mean values column wise
california_df.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
# Standard Deviation column wise
california_df.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# dtype: float64

# %%
# Describe the dataset
california_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
print(california_dataset)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
# adding price column to the dataframe
california_df['Price'] = california_dataset.target

# %%
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
california_df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894

# %%
# Remove Row from DataFrame
california_df.drop(index=0, axis=0)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
# Removing column from DataFrame
california_df.drop(columns=['Latitude', 'Longitude'], axis=1)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Price
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556  4.526
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842  3.585
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260  3.521
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945  3.413
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467  3.422
# ...       ...       ...       ...        ...         ...       ...    ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606  0.781
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807  0.771
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635  0.923
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209  0.847
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981  0.894
#
# [20640 rows x 7 columns]

# %% [markdown]
# ### Correlation

# %%
# Positive Correaltion -> When one variable increases the other variable also increases.
# e.g. HouseArea increases -> Price increases.

# Negative Correlation -> When one variable increases the other variable decreases.
# e.g. HouseAge increases -> Price decreases.

california_df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...
